# %%
import numpy as np

# %%
# !rm -fr ed_model_dirs

# %%
for i in 2, 4, 8, 16, 32, 64, 128:
    print(i)
    # !sleep 5
    hidden_units = '512,256,128,%d' % i
    name = '%d' % i
    # !python3 ed.py \
    --learning_rate 0.0001 \
    --hidden_units $hidden_units \
    --fresh_start \
    --name $name \
    --batch_size 500 \
    --dropout_rate 0.0 \
    --l1_regularizer 0.0000001 \
    --n_features 1000 \
    > /dev/null 2>&1
# Out:
# 2
# 4
# 8
# 16
# 32

# %%
for i in 2, 4, 8, 16, 32, 64, 128:
    print(i)
    # !sleep 5
    hidden_units = '512,256,128,%d' % i
    name = 'AAA%d' % i
    # !python3 ed.py \
    --learning_rate 0.0001 \
    --hidden_units $hidden_units \
    --fresh_start \
    --name $name \
    --batch_size 500 \
    --dropout_rate 0.0 \
    --l1_regularizer 0.0000001 \
    --n_features 1000 \
    > /dev/null 2>&1
# Out:
# 2
# 4
# 8
# 16
# 32
# 64
# 128

# %%
for i in 2, 4, 8, 16, 32, 64, 128:
    # !python3 ed_export.py --folder ed_model_dirs/AAA$i
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# {'batch_size': 500,
#  'dropout_rate': 0.0,
#  'export_name': './ed_model_dirs/AAA2/result/',
#  'fresh_start': True,
#  'hidden_units': [512, 256, 128, 2],
#  'l1_regularizer': 1e-07,
#  'l2_regularizer': 1e-10,
#  'learning_rate': 0.0001,
#  'log_input': False,
#  'max_not_improve': 25,
#  'max_steps': 3000000,
#  'model_dir': './ed_model_dirs/AAA2/',
#  'n_features': 1000,
#  'name': 'AAA2',
#  'noise_level': 0}
# best_step 41500
# 2018-08-13 20:18:18.449546: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-08-13 20:18:18.450044: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.92GiB freeMemory: 10.76GiB
# 2018-08-13 20:18:18.450061: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:18.654022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:18.654062: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:18.654076: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:18.654311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /home/evo/.local/lib/python3.5/site-packages/pandas/io/pytables.py:281: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   f(store)
# 2018-08-13 20:18:19.220121: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:19.220172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:19.220183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:19.220209: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:19.220324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-08-13 20:18:20.377999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:20.378052: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:20.378063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:20.378074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:20.378194: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# {'batch_size': 500,
#  'dropout_rate': 0.0,
#  'export_name': './ed_model_dirs/AAA4/result/',
#  'fresh_start': True,
#  'hidden_units': [512, 256, 128, 4],
#  'l1_regularizer': 1e-07,
#  'l2_regularizer': 1e-10,
#  'learning_rate': 0.0001,
#  'log_input': False,
#  'max_not_improve': 25,
#  'max_steps': 3000000,
#  'model_dir': './ed_model_dirs/AAA4/',
#  'n_features': 1000,
#  'name': 'AAA4',
#  'noise_level': 0}
# best_step 56500
# 2018-08-13 20:18:27.164385: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-08-13 20:18:27.164893: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.92GiB freeMemory: 10.76GiB
# 2018-08-13 20:18:27.164911: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:27.372283: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:27.372321: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:27.372328: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:27.372561: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /home/evo/.local/lib/python3.5/site-packages/pandas/io/pytables.py:281: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   f(store)
# 2018-08-13 20:18:27.932075: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:27.932127: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:27.932138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:27.932148: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:27.932261: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-08-13 20:18:29.140816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:29.140871: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:29.140884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:29.140891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:29.141024: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# {'batch_size': 500,
#  'dropout_rate': 0.0,
#  'export_name': './ed_model_dirs/AAA8/result/',
#  'fresh_start': True,
#  'hidden_units': [512, 256, 128, 8],
#  'l1_regularizer': 1e-07,
#  'l2_regularizer': 1e-10,
#  'learning_rate': 0.0001,
#  'log_input': False,
#  'max_not_improve': 25,
#  'max_steps': 3000000,
#  'model_dir': './ed_model_dirs/AAA8/',
#  'n_features': 1000,
#  'name': 'AAA8',
#  'noise_level': 0}
# best_step 59000
# 2018-08-13 20:18:35.741325: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-08-13 20:18:35.741864: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.92GiB freeMemory: 10.76GiB
# 2018-08-13 20:18:35.741882: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:35.948816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:35.948854: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:35.948869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:35.949100: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /home/evo/.local/lib/python3.5/site-packages/pandas/io/pytables.py:281: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   f(store)
# 2018-08-13 20:18:36.541592: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:36.541641: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:36.541649: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:36.541658: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:36.541797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-08-13 20:18:37.813872: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:37.813926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:37.813936: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:37.813942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:37.814084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# {'batch_size': 500,
#  'dropout_rate': 0.0,
#  'export_name': './ed_model_dirs/AAA16/result/',
#  'fresh_start': True,
#  'hidden_units': [512, 256, 128, 16],
#  'l1_regularizer': 1e-07,
#  'l2_regularizer': 1e-10,
#  'learning_rate': 0.0001,
#  'log_input': False,
#  'max_not_improve': 25,
#  'max_steps': 3000000,
#  'model_dir': './ed_model_dirs/AAA16/',
#  'n_features': 1000,
#  'name': 'AAA16',
#  'noise_level': 0}
# best_step 52000
# 2018-08-13 20:18:44.468115: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-08-13 20:18:44.468665: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.92GiB freeMemory: 10.76GiB
# 2018-08-13 20:18:44.468687: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:44.686471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:44.686513: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:44.686525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:44.686794: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /home/evo/.local/lib/python3.5/site-packages/pandas/io/pytables.py:281: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   f(store)
# 2018-08-13 20:18:45.268876: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:45.268921: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:45.268929: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:45.268935: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:45.269048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-08-13 20:18:46.417371: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:46.417424: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:46.417433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:46.417440: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:46.417576: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# {'batch_size': 500,
#  'dropout_rate': 0.0,
#  'export_name': './ed_model_dirs/AAA32/result/',
#  'fresh_start': True,
#  'hidden_units': [512, 256, 128, 32],
#  'l1_regularizer': 1e-07,
#  'l2_regularizer': 1e-10,
#  'learning_rate': 0.0001,
#  'log_input': False,
#  'max_not_improve': 25,
#  'max_steps': 3000000,
#  'model_dir': './ed_model_dirs/AAA32/',
#  'n_features': 1000,
#  'name': 'AAA32',
#  'noise_level': 0}
# best_step 54500
# 2018-08-13 20:18:53.265926: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-08-13 20:18:53.266445: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.92GiB freeMemory: 10.76GiB
# 2018-08-13 20:18:53.266462: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:53.473737: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:53.473774: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:53.473784: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:53.481093: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /home/evo/.local/lib/python3.5/site-packages/pandas/io/pytables.py:281: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   f(store)
# 2018-08-13 20:18:54.050116: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:54.050163: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:54.050171: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:54.050177: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:54.050323: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-08-13 20:18:55.214752: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:18:55.214805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:18:55.214815: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:18:55.214825: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:18:55.214976: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# {'batch_size': 500,
#  'dropout_rate': 0.0,
#  'export_name': './ed_model_dirs/AAA64/result/',
#  'fresh_start': True,
#  'hidden_units': [512, 256, 128, 64],
#  'l1_regularizer': 1e-07,
#  'l2_regularizer': 1e-10,
#  'learning_rate': 0.0001,
#  'log_input': False,
#  'max_not_improve': 25,
#  'max_steps': 3000000,
#  'model_dir': './ed_model_dirs/AAA64/',
#  'n_features': 1000,
#  'name': 'AAA64',
#  'noise_level': 0}
# best_step 85000
# 2018-08-13 20:19:02.058150: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-08-13 20:19:02.058657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.92GiB freeMemory: 10.76GiB
# 2018-08-13 20:19:02.058675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:19:02.262041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:19:02.262080: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:19:02.262088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:19:02.262342: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /home/evo/.local/lib/python3.5/site-packages/pandas/io/pytables.py:281: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   f(store)
# 2018-08-13 20:19:02.900302: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:19:02.900353: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:19:02.900362: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:19:02.900369: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:19:02.900503: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-08-13 20:19:04.074980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:19:04.075029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:19:04.075036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:19:04.075043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:19:04.075186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# {'batch_size': 500,
#  'dropout_rate': 0.0,
#  'export_name': './ed_model_dirs/AAA128/result/',
#  'fresh_start': True,
#  'hidden_units': [512, 256, 128, 128],
#  'l1_regularizer': 1e-07,
#  'l2_regularizer': 1e-10,
#  'learning_rate': 0.0001,
#  'log_input': False,
#  'max_not_improve': 25,
#  'max_steps': 3000000,
#  'model_dir': './ed_model_dirs/AAA128/',
#  'n_features': 1000,
#  'name': 'AAA128',
#  'noise_level': 0}
# best_step 65000
# 2018-08-13 20:19:11.324552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-08-13 20:19:11.325067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.92GiB freeMemory: 10.76GiB
# 2018-08-13 20:19:11.325084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:19:11.534147: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:19:11.534187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:19:11.534202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:19:11.534428: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /home/evo/.local/lib/python3.5/site-packages/pandas/io/pytables.py:281: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   f(store)
# 2018-08-13 20:19:12.205803: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:19:12.205855: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:19:12.205862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:19:12.205868: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:19:12.205985: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-08-13 20:19:13.353221: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-13 20:19:13.353274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-13 20:19:13.353284: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-13 20:19:13.353290: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-13 20:19:13.353424: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10409 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
